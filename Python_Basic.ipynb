# %% [markdown]
# <a href="https://colab.research.google.com/github/momdadkishan89-dot/DSVLAB/blob/main/Python_Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3;
y=3.0;
print(x==y);
# Out:
# True

# %%
x="kishan";
x=x.upper();
print(x);
# Out:
# KISHAN

# %%
name = input ("Enter your name ")
print("Hello!",name,"welcome to python")
number=input ("enter your number")
number=int(input("enter your number"))
print(type( number))
# Out:
# Enter your name kishan
# Hello! kishan welcome to python
# enter your number8004697043
# enter your number8004697043
# <class 'int'>

# %%
name = input("enter your name")
contact = input ("enter your contact")
address = input ("enter your address")
uniroll=input("enter your uniroll")
print(name)
print(contact)
print(address)
print(uniroll)
# Out:
# enter your namekishan
# enter your contact8004697043
# enter your addressballia
# enter your uniroll12515000812
# kishan
# 8004697043
# ballia
# 12515000812

# %%
limit=int(input("Enter limit: "))
print("odd number upto",limit,"are")
for i in range(1,limit+1,2):
    print(i)
# Out:
# Enter limit: 10
# odd number upto 10 are
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(1, 6):
  print("* " * i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n=0
while n<6:
  print("* " *n)
  n+=1
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
limit = int(input("Enter limit: "))
print("Odd numbers up to", limit, "are")

for i in range(1, limit + 1, 2):
    print(i)
# Out:
# Enter limit: 10
# Odd numbers up to 10 are
# 1
# 3
# 5
# 7
# 9

# %%
n=1;
while(n<10):
  print(n)
  n+=1;
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
dict_con= {
    'Kunal':5623456,
    'Rahul':789456,
    'Pratap':741258
}
name = input("Enter the name: ")
for i in dict_con:
  if(i==name):
    print(dict_con[i])
    break
print("Name not found")
# Out:
# Enter the name: Rahul
# 789456
# Name not found
